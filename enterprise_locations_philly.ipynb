# %%
df = {
    'Address':['36 S 19th St, Philadelphia, PA 19103',
    '727 Chestnut St, Philadelphia, PA 19106',
    '1236-40 Washington Ave, Philadelphia, PA 19147',
    '5847 N Broad St, Philadelphia, PA 19141',
    '1 Arrivals Rd, Philadelphia, PA 19153',
    '15 S 36th St, Philadelphia, PA 19104',
    '510 N Front St, Philadelphia, PA 19123',
    '7601 Roosevelt Blvd, Philadelphia, PA 19152',
    '1201 E Erie Ave, Philadelphia, PA 19124',
    '217 W Chelten Ave 233, Philadelphia, PA 19144',
    '7001 Essington Ave, Philadelphia, PA 19153',
    '6820-26 Castor Ave, Philadelphia, PA 19149',
    '10100 Bustleton Ave, Philadelphia, PA 19116',
    '6800 Rising Sun Ave, Philadelphia, PA 19111',
    '110 Leverington Ave, Philadelphia, PA 19127',
    '8913 Frankford Ave, Philadelphia, PA 19136',
    '6801 Germantown Ave, Philadelphia, PA 19119',
    '1627 W Cheltenham Ave, Elkins Park, PA 19027',
    '217 Bala Ave, Bala Cynwyd, PA 19004',
    '25 City Ave, Bala Cynwyd, PA 19004']}

# %%
import pandas as pd
df = pd.DataFrame(df)
df
# Out:
#                                            Address
# 0             36 S 19th St, Philadelphia, PA 19103
# 1          727 Chestnut St, Philadelphia, PA 19106
# 2   1236-40 Washington Ave, Philadelphia, PA 19147
# 3          5847 N Broad St, Philadelphia, PA 19141
# 4            1 Arrivals Rd, Philadelphia, PA 19153
# 5             15 S 36th St, Philadelphia, PA 19104
# 6           510 N Front St, Philadelphia, PA 19123
# 7      7601 Roosevelt Blvd, Philadelphia, PA 19152
# 8          1201 E Erie Ave, Philadelphia, PA 19124
# 9    217 W Chelten Ave 233, Philadelphia, PA 19144
# 10      7001 Essington Ave, Philadelphia, PA 19153
# 11      6820-26 Castor Ave, Philadelphia, PA 19149
# 12     10100 Bustleton Ave, Philadelphia, PA 19116
# 13     6800 Rising Sun Ave, Philadelphia, PA 19111
# 14     110 Leverington Ave, Philadelphia, PA 19127
# 15      8913 Frankford Ave, Philadelphia, PA 19136
# 16     6801 Germantown Ave, Philadelphia, PA 19119
# ...

# %%
import googlemaps

# %%
gmaps_key = googlemaps.Client(key='AIzaSyCU4QbSmC_dpge_Vh03599sXccRe9zEBaQ')

# %%
add_1 = df['Address'][0]
g = gmaps_key.geocode(add_1)
lat = g[0]['geometry']['location']['lat']
long = g[0]['geometry']['location']['lng']
print('Latitude: '+str(lat)+', Longitude: '+str(long))
# Out:
# Latitude: 39.9526505, Longitude: -75.1721816

# %%
def geocode(add):
    g = gmaps_key.geocode(add)
    lat = g[0]['geometry']['location']['lat']
    lng = g[0]['geometry']['location']['lng']
    return(lat,lng)

df['geocoded'] = df['Address'].apply(geocode)

# %%
df.head(20)
# Out:
#                                            Address  \
# 0             36 S 19th St, Philadelphia, PA 19103
# 1          727 Chestnut St, Philadelphia, PA 19106
# 2   1236-40 Washington Ave, Philadelphia, PA 19147
# 3          5847 N Broad St, Philadelphia, PA 19141
# 4            1 Arrivals Rd, Philadelphia, PA 19153
# 5             15 S 36th St, Philadelphia, PA 19104
# 6           510 N Front St, Philadelphia, PA 19123
# 7      7601 Roosevelt Blvd, Philadelphia, PA 19152
# 8          1201 E Erie Ave, Philadelphia, PA 19124
# 9    217 W Chelten Ave 233, Philadelphia, PA 19144
# 10      7001 Essington Ave, Philadelphia, PA 19153
# 11      6820-26 Castor Ave, Philadelphia, PA 19149
# 12     10100 Bustleton Ave, Philadelphia, PA 19116
# 13     6800 Rising Sun Ave, Philadelphia, PA 19111
# 14     110 Leverington Ave, Philadelphia, PA 19127
# 15      8913 Frankford Ave, Philadelphia, PA 19136
# 16     6801 Germantown Ave, Philadelphia, PA 19119
# ...

# %%
df.to_csv('enterprise_corrdinates.csv')

# %%
df['geocoded'].count()
# Out:
# 20

# %%
import pandas as pd
import geopandas
import folium
import matplotlib.pyplot as plt

# %%
airport_addy = '8000 Essington Ave, Philadelphia, PA 19153'


air= gmaps_key.geocode(airport_addy)
lat = air[0]['geometry']['location']['lat']
long = air[0]['geometry']['location']['lng']
print('Latitude: '+str(lat)+', Longitude: '+str(long))
# Out:
# Latitude: 39.8951784, Longitude: -75.2279726

# %%
m = folium.Map(location=[39.8951784, -75.2279726], zoom_start=12, tiles="Enterprise Rentals")

folium.Marker(
    location=df['geocoded'][0],
    popup="Location 1",
    icon=folium.Icon(icon="cloud"),
).add_to(m)

folium.Marker(
    location=df['geocoded'][1],
    popup="Location 2",
    icon=folium.Icon(color="green"),
).add_to(m)


m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4y/fqmz2ns51h9ft17q2fxdbf3w0000gn/T/ipykernel_44425/4073150833.py in <module>
# ----> 1 m = folium.Map(location=[39.8951784, -75.2279726], zoom_start=12, tiles="Enterprise Rentals")
#       2
#       3 folium.Marker(
#       4     location=df['geocoded'][0],
#       5     popup="Location 1",
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/folium.py in __init__(self, location, width, height, left, top, position, tiles, attr, min_zoom, max_zoom, zoom_start, min_lat, max_lat, min_lon, max_lon, max_bounds, crs, control_scale, prefer_canvas, no_touch, disable_3d, png_enabled, zoom_control, **kwargs)
#     286
#     287         if tiles:
# --> 288             tile_layer = TileLayer(tiles=tiles, attr=attr,
#     289                                    min_zoom=min_zoom, max_zoom=max_zoom)
# ...

# %%
m = folium.Map(location=[39.8951784, -75.2279726], zoom_start=13)
folium.Marker(
    df['geocoded'][0], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][1], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][2], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][3], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][4], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][5], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][6], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][7], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][8], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][9], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][10], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][11], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][12], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][13], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][14], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][15], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][16], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][17], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][18], popup="Location 1"
).add_to(m)
folium.Marker(
    df['geocoded'][19], popup="Location 1"
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
